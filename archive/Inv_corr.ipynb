# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import pickle as pkl
import scipy

from radis import calc_spectrum
from radis import load_spec
from radis.test.utils import getTestFile
from radis import Spectrum

from Toolbox_Processing import *
from Toolbox_Reading import *
from Toolbox_Inversion import *
from Toolbox_Display import *


x_sol = np.load('EmFit_private/results/sol.npy')
sigma = np.load('EmFit_private/results/sig.npy')
Compounds = np.load('EmFit_private/results/comp.npy', allow_pickle=True).item()
ref_spec = np.load('EmFit_private/results/ref.npy')
obs_spec = np.load('EmFit_private/results/obs.npy')
W = np.load('W.npy')


with open('EmFit_private/results/C.pickle', 'rb') as handle:
    C = pkl.load(handle)



c_inv = np.linalg.inv(C.toarray())
std_devs = np.sqrt(np.diag(c_inv))

# Use broadcasting to calculate the correlation matrix
inv_corr = c_inv/ np.outer(std_devs, std_devs)


#plt.imshow(inv_corr, vmin=-0.1,vmax=.1, cmap=plt.cm.RdBu)
#plt.savefig('posterior.png')

# from statsmodels.tsa.stattools import grangercausalitytests

# data = x_sol.reshape(-1, 567)

# from scipy.stats import kendalltau


# print(Compounds.keys())


# for i in range(len(list(Compounds.keys()))):
#     tau, p_value = kendalltau(data[5], data[i])
#     print(p_value, tau)


# data = x_sol.reshape(-1, 567)
# tau, p_value = kendalltau(data[5], data[2])









# lasso_inversion = np.load('EmFit_private/results/lasso_evaluation.npy', allow_pickle=True).item()

# print(lasso_inversion['Cross Validation Score'])

# plt.plot(lasso_inversion['Timesteps'], lasso_inversion['Cross Validation Score'][0])
# plt.savefig('lasso.jpg')

# c_inv = np.linalg.inv(C.toarray())
# plt.imshow(c_inv, interpolation="nearest", cmap=plt.get_cmap("RdBu"))
# plt.savefig('Cov.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> from Toolbox_Inversion import *
#      <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> from Toolbox_Display import *
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> x_sol = np.load('EmFit_private/results/sol.npy')
#      <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> sigma = np.load('EmFit_private/results/sig.npy')
#      <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> Compounds = np.load('EmFit_private/results/comp.npy', allow_pickle=True).item()
#
# File ~/.mambaforge/lib/python3.10/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'EmFit_private/results/sol.npy'

# %%
pwd
# Out:
# '/home/luke/lukeflamingradis/EmFit_private'

# %%
cwd ..
# Out:
#   Cell In[3], line 1
#     cwd ..
#          ^
# SyntaxError: invalid syntax

# %%
import os
os.cwd("..")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 os.cwd("..")
#
# AttributeError: module 'os' has no attribute 'cwd'

# %%
import os
os.cd("..")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 os.cd("..")
#
# AttributeError: module 'os' has no attribute 'cd'

# %%
os.chdir("..")

# %%
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import pickle as pkl
import scipy

from radis import calc_spectrum
from radis import load_spec
from radis.test.utils import getTestFile
from radis import Spectrum

from Toolbox_Processing import *
from Toolbox_Reading import *
from Toolbox_Inversion import *
from Toolbox_Display import *


x_sol = np.load('EmFit_private/results/sol.npy')
sigma = np.load('EmFit_private/results/sig.npy')
Compounds = np.load('EmFit_private/results/comp.npy', allow_pickle=True).item()
ref_spec = np.load('EmFit_private/results/ref.npy')
obs_spec = np.load('EmFit_private/results/obs.npy')
W = np.load('W.npy')


with open('EmFit_private/results/C.pickle', 'rb') as handle:
    C = pkl.load(handle)



c_inv = np.linalg.inv(C.toarray())
std_devs = np.sqrt(np.diag(c_inv))

# Use broadcasting to calculate the correlation matrix
inv_corr = c_inv/ np.outer(std_devs, std_devs)


#plt.imshow(inv_corr, vmin=-0.1,vmax=.1, cmap=plt.cm.RdBu)
#plt.savefig('posterior.png')

# from statsmodels.tsa.stattools import grangercausalitytests

# data = x_sol.reshape(-1, 567)

# from scipy.stats import kendalltau


# print(Compounds.keys())


# for i in range(len(list(Compounds.keys()))):
#     tau, p_value = kendalltau(data[5], data[i])
#     print(p_value, tau)


# data = x_sol.reshape(-1, 567)
# tau, p_value = kendalltau(data[5], data[2])









# lasso_inversion = np.load('EmFit_private/results/lasso_evaluation.npy', allow_pickle=True).item()

# print(lasso_inversion['Cross Validation Score'])

# plt.plot(lasso_inversion['Timesteps'], lasso_inversion['Cross Validation Score'][0])
# plt.savefig('lasso.jpg')

# c_inv = np.linalg.inv(C.toarray())
# plt.imshow(c_inv, interpolation="nearest", cmap=plt.get_cmap("RdBu"))
# plt.savefig('Cov.jpg')

# %%
inv_corr.diagonal()
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
inv_corr.diagonal(k=-1
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 inv_corr.diagonal(k=-1
#       2 )
#
# TypeError: 'k' is an invalid keyword argument for diagonal()

# %%
inv_corr.diagonal(-1)
# Out:
# array([0.09100458, 0.08704815, 0.08700929, ..., 0.18932164, 0.19000841,
#        0.20631692])

# %%
inv_corr.diagonal(-2)
# Out:
# array([0.00829808, 0.00791168, 0.00790757, ..., 0.0365168 , 0.03666493,
#        0.04003652])

# %%
plt.imshow(np.log10(inv_corr))
# Out:
# <ipython-input-12-d8d372fb965f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(inv_corr))
# <ipython-input-12-d8d372fb965f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(inv_corr))

# %%
plt.show()

# %%
from matplotlib.colors import LogNorm;plt.imsho(inv_corr, cmap="magma", norm=LogNorm())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from matplotlib.colors import LogNorm;plt.imsho(inv_corr, cmap="magma", norm=LogNorm())
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'imsho'

# %%
from matplotlib.colors import LogNorm;plt.imshow(inv_corr, cmap="magma", norm=LogNorm())

# %%
from matplotlib.colors import LogNorm;plt.imshow(inv_corr, vmin=-1, vmax=1, norm=LogNorm())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from matplotlib.colors import LogNorm;plt.imshow(inv_corr, vmin=-1, vmax=1, norm=LogNorm())
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3324'>3325</a> @_copy_docstring_and_deprecators(Axes.imshow)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3325'>3326</a> def imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3326'>3327</a>     X: ArrayLike | PIL.Image.Image,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3343'>3344</a>     **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3344'>3345</a> ) -> AxesImage:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3345'>3346</a>     __ret = gca().imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3346'>3347</a>         X,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3347'>3348</a>         cmap=cmap,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3348'>3349</a>         norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3349'>3350</a>         aspect=aspect,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3350'>3351</a>         interpolation=interpolation,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3351'>3352</a>         alpha=alpha,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3352'>3353</a>         vmin=vmin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3353'>3354</a>         vmax=vmax,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3354'>3355</a>         origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3355'>3356</a>         extent=extent,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3356'>3357</a>         interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3357'>3358</a>         filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3358'>3359</a>         filterrad=filterrad,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3359'>3360</a>         resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3360'>3361</a>         url=url,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3361'>3362</a>         **({"data": data} if data is not None else {}),
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3362'>3363</a>         **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3363'>3364</a>     )
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3364'>3365</a>     sci(__ret)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3365'>3366</a>     return __ret
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1461'>1462</a> @functools.wraps(func)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1462'>1463</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1463'>1464</a>     if data is None:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1464'>1465</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1466'>1467</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1467'>1468</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1468'>1469</a>                   or bound.kwargs.get(label_namer))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5752'>5753</a> if im.get_clip_path() is None:
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5753'>5754</a>     # image does not already have clipping set, clip to axes patch
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5754'>5755</a>     im.set_clip_path(self.patch)
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5755'>5756</a> im._scale_norm(norm, vmin, vmax)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5756'>5757</a> im.set_url(url)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5758'>5759</a> # update ax.dataLim, and, if autoscaling, set viewLim
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5759'>5760</a> # to tightly fit the image, regardless of dataLim.
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:429, in ScalarMappable._scale_norm(self, norm, vmin, vmax)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=426'>427</a>     self.set_clim(vmin, vmax)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=427'>428</a>     if isinstance(norm, colors.Normalize):
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=428'>429</a>         raise ValueError(
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=429'>430</a>             "Passing a Normalize instance simultaneously with "
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=430'>431</a>             "vmin/vmax is not supported.  Please pass vmin/vmax "
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=431'>432</a>             "directly to the norm when creating it.")
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=433'>434</a> # always resolve the autoscaling so we have concrete limits
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=434'>435</a> # rather than deferring to draw time.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=435'>436</a> self.autoscale_None()
#
# ValueError: Passing a Normalize instance simultaneously with vmin/vmax is not supported.  Please pass vmin/vmax directly to the norm when creating it.

# %%
from matplotlib.colors import LogNorm;plt.imshow(inv_corr,  norm=LogNorm())

# %%
plt.show()

# %%
inv_clean = np.where(np.abs(inv_corr) < 0.1, np.nan, inv_corr )

# %%
from matplotlib.colors import LogNorm;plt.imshow(inv_clean,  vmin=-0.1, vmax=0.1)

# %%
plt.show()

# %%
plt.imshow(inv_clean)

# %%
plt.show()

# %%
inv_clean.diagonal(-1)
# Out:
# array([       nan,        nan,        nan, ..., 0.18932164, 0.19000841,
#        0.20631692])

# %%
np.isnan(inv_clean.diagonal(-1)).sum()
# Out:
# 4540

# %%
inv_clean = np.where(np.abs(inv_corr) < 0.01, np.nan, inv_corr )

# %%
plt.imshow(inv_clean);plt.show()

# %%
plt.imshow(inv_clean,vmin=-0.2, vmax=0.2);plt.show()

# %%
plt.imshow(inv_clean,vmin=-0.02, vmax=0.02);plt.show()

# %%
plt.imshow(inv_clean, norm=LogNorm());plt.show()

# %%
plt.spy(inv_clean)

# %%
plt.imshow(np.log10(inv_corr))
# Out:
# <ipython-input-32-d8d372fb965f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(inv_corr))
# <ipython-input-32-d8d372fb965f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(inv_corr))

# %%
from matplotlib.colors import LogNorm;
plt.imshow(inv_corr, vmin=-1, vmax=1, norm=LogNorm())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 from matplotlib.colors import LogNorm;
# ----> 2 plt.imshow(inv_corr, vmin=-1, vmax=1, norm=LogNorm())
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3324'>3325</a> @_copy_docstring_and_deprecators(Axes.imshow)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3325'>3326</a> def imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3326'>3327</a>     X: ArrayLike | PIL.Image.Image,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3343'>3344</a>     **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3344'>3345</a> ) -> AxesImage:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3345'>3346</a>     __ret = gca().imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3346'>3347</a>         X,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3347'>3348</a>         cmap=cmap,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3348'>3349</a>         norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3349'>3350</a>         aspect=aspect,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3350'>3351</a>         interpolation=interpolation,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3351'>3352</a>         alpha=alpha,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3352'>3353</a>         vmin=vmin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3353'>3354</a>         vmax=vmax,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3354'>3355</a>         origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3355'>3356</a>         extent=extent,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3356'>3357</a>         interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3357'>3358</a>         filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3358'>3359</a>         filterrad=filterrad,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3359'>3360</a>         resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3360'>3361</a>         url=url,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3361'>3362</a>         **({"data": data} if data is not None else {}),
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3362'>3363</a>         **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3363'>3364</a>     )
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3364'>3365</a>     sci(__ret)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3365'>3366</a>     return __ret
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1461'>1462</a> @functools.wraps(func)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1462'>1463</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1463'>1464</a>     if data is None:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1464'>1465</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1466'>1467</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1467'>1468</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1468'>1469</a>                   or bound.kwargs.get(label_namer))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5752'>5753</a> if im.get_clip_path() is None:
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5753'>5754</a>     # image does not already have clipping set, clip to axes patch
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5754'>5755</a>     im.set_clip_path(self.patch)
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5755'>5756</a> im._scale_norm(norm, vmin, vmax)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5756'>5757</a> im.set_url(url)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5758'>5759</a> # update ax.dataLim, and, if autoscaling, set viewLim
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5759'>5760</a> # to tightly fit the image, regardless of dataLim.
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:429, in ScalarMappable._scale_norm(self, norm, vmin, vmax)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=426'>427</a>     self.set_clim(vmin, vmax)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=427'>428</a>     if isinstance(norm, colors.Normalize):
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=428'>429</a>         raise ValueError(
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=429'>430</a>             "Passing a Normalize instance simultaneously with "
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=430'>431</a>             "vmin/vmax is not supported.  Please pass vmin/vmax "
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=431'>432</a>             "directly to the norm when creating it.")
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=433'>434</a> # always resolve the autoscaling so we have concrete limits
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=434'>435</a> # rather than deferring to draw time.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=435'>436</a> self.autoscale_None()
#
# ValueError: Passing a Normalize instance simultaneously with vmin/vmax is not supported.  Please pass vmin/vmax directly to the norm when creating it.

# %%
from matplotlib.colors import LogNorm;
plt.imshow(inv_corr, norm=LogNorm())

# %%
plt.imshow(np.log10(inv_corr))
# Out:
# <ipython-input-35-d8d372fb965f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(inv_corr))
# <ipython-input-35-d8d372fb965f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(inv_corr))

# %%
plt.imshow(inv_corr)

# %%
print(np.min(inv_corr))
# Out:
# -0.21773308501372632

# %%
plt.imshow(inv_corr, vmin=-0.1, vmax=0.1)

# %%
plt.imshow(np.log10(abs(inv_corr)))
# Out:
# <ipython-input-39-09df88f6f0b2>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(abs(inv_corr)))

# %%
from matplotlib.colors import LogNorm;
plt.imshow(inv_corr, norm=LogNorm())

# %%
np.linalg.rcond(c_inv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 np.linalg.rcond(c_inv)
#
# AttributeError: module 'numpy.linalg' has no attribute 'rcond'

# %%
np.linalg.cond(c_inv)
# Out:
# 1335.6432951087036

# %%
plt.imshow(np.log10(-inv_corr))
# Out:
# <ipython-input-43-4262d09187bd>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr))
# <ipython-input-43-4262d09187bd>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr))

# %%
plt.imshow(np.log10(-inv_corr),cmap='RbGu')
plt.imshow(np.log10(-inv_corr))
# Out:
# <ipython-input-44-e85c2ff0886b>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='RbGu')
# <ipython-input-44-e85c2ff0886b>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='RbGu')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 plt.imshow(np.log10(-inv_corr),cmap='RbGu')
#       2 plt.imshow(np.log10(-inv_corr))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3324'>3325</a> @_copy_docstring_and_deprecators(Axes.imshow)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3325'>3326</a> def imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3326'>3327</a>     X: ArrayLike | PIL.Image.Image,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3343'>3344</a>     **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3344'>3345</a> ) -> AxesImage:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3345'>3346</a>     __ret = gca().imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3346'>3347</a>         X,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3347'>3348</a>         cmap=cmap,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3348'>3349</a>         norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3349'>3350</a>         aspect=aspect,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3350'>3351</a>         interpolation=interpolation,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3351'>3352</a>         alpha=alpha,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3352'>3353</a>         vmin=vmin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3353'>3354</a>         vmax=vmax,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3354'>3355</a>         origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3355'>3356</a>         extent=extent,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3356'>3357</a>         interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3357'>3358</a>         filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3358'>3359</a>         filterrad=filterrad,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3359'>3360</a>         resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3360'>3361</a>         url=url,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3361'>3362</a>         **({"data": data} if data is not None else {}),
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3362'>3363</a>         **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3363'>3364</a>     )
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3364'>3365</a>     sci(__ret)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3365'>3366</a>     return __ret
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1461'>1462</a> @functools.wraps(func)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1462'>1463</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1463'>1464</a>     if data is None:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1464'>1465</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1466'>1467</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1467'>1468</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1468'>1469</a>                   or bound.kwargs.get(label_namer))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5737, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5531'>5532</a> @_preprocess_data()
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5532'>5533</a> @_docstring.interpd
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5533'>5534</a> def imshow(self, X, cmap=None, norm=None, *, aspect=None,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5536'>5537</a>            interpolation_stage=None, filternorm=True, filterrad=4.0,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5537'>5538</a>            resample=None, url=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5538'>5539</a>     """
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5539'>5540</a>     Display data as an image, i.e., on a 2D regular raster.
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5540'>5541</a>
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5734'>5735</a>     (unassociated) alpha representation.
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5735'>5736</a>     """
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5736'>5737</a>     im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5737'>5738</a>                           interpolation=interpolation, origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5738'>5739</a>                           extent=extent, filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5739'>5740</a>                           filterrad=filterrad, resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5740'>5741</a>                           interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5741'>5742</a>                           **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5743'>5744</a>     if aspect is None and not (
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5744'>5745</a>             im.is_transform_set()
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5745'>5746</a>             and not im.get_transform().contains_branch(self.transData)):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5746'>5747</a>         aspect = mpl.rcParams['image.aspect']
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py:912, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=895'>896</a> def __init__(self, ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=896'>897</a>              *,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=897'>898</a>              cmap=None,
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=906'>907</a>              **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=907'>908</a>              ):
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=909'>910</a>     self._extent = extent
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=911'>912</a>     super().__init__(
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=912'>913</a>         ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=913'>914</a>         cmap=cmap,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=914'>915</a>         norm=norm,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=915'>916</a>         interpolation=interpolation,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=916'>917</a>         origin=origin,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=917'>918</a>         filternorm=filternorm,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=918'>919</a>         filterrad=filterrad,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=919'>920</a>         resample=resample,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=920'>921</a>         interpolation_stage=interpolation_stage,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=921'>922</a>         **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=922'>923</a>     )
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py:261, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=247'>248</a> def __init__(self, ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=248'>249</a>              cmap=None,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=249'>250</a>              norm=None,
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=257'>258</a>              **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=258'>259</a>              ):
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=259'>260</a>     martist.Artist.__init__(self)
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=260'>261</a>     cm.ScalarMappable.__init__(self, norm, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=261'>262</a>     if origin is None:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=262'>263</a>         origin = mpl.rcParams['image.origin']
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:411, in ScalarMappable.__init__(self, norm, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=408'>409</a> self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=409'>410</a> self.cmap = None  # So that the setter knows we're initializing.
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=410'>411</a> self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=411'>412</a> #: The last colorbar associated with this ScalarMappable. May be None.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=412'>413</a> self.colorbar = None
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:600, in ScalarMappable.set_cmap(self, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=590'>591</a> """
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=591'>592</a> Set the colormap for luminance data.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=592'>593</a>
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=595'>596</a> cmap : `.Colormap` or str or None
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=596'>597</a> """
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=597'>598</a> in_init = self.cmap is None
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=599'>600</a> self.cmap = _ensure_cmap(cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=600'>601</a> if not in_init:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=601'>602</a>     self.changed()
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:739, in _ensure_cmap(cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=735'>736</a> # use check_in_list to ensure type stability of the exception raised by
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=736'>737</a> # the internal usage of this (ValueError vs KeyError)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=737'>738</a> if cmap_name not in _colormaps:
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=738'>739</a>     _api.check_in_list(sorted(_colormaps), cmap=cmap_name)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=739'>740</a> return mpl.colormaps[cmap_name]
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py:129, in check_in_list(values, _print_supported_values, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=126'>127</a> if _print_supported_values:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=127'>128</a>     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=128'>129</a> raise ValueError(msg)
#
# ValueError: 'RbGu' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
plt.imshow(np.log10(-inv_corr),cmap='Magma')
plt.imshow(np.log10(-inv_corr))
# Out:
# <ipython-input-45-81571593ca4f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='Magma')
# <ipython-input-45-81571593ca4f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='Magma')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 plt.imshow(np.log10(-inv_corr),cmap='Magma')
#       2 plt.imshow(np.log10(-inv_corr))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3324'>3325</a> @_copy_docstring_and_deprecators(Axes.imshow)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3325'>3326</a> def imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3326'>3327</a>     X: ArrayLike | PIL.Image.Image,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3343'>3344</a>     **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3344'>3345</a> ) -> AxesImage:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3345'>3346</a>     __ret = gca().imshow(
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3346'>3347</a>         X,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3347'>3348</a>         cmap=cmap,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3348'>3349</a>         norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3349'>3350</a>         aspect=aspect,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3350'>3351</a>         interpolation=interpolation,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3351'>3352</a>         alpha=alpha,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3352'>3353</a>         vmin=vmin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3353'>3354</a>         vmax=vmax,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3354'>3355</a>         origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3355'>3356</a>         extent=extent,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3356'>3357</a>         interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3357'>3358</a>         filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3358'>3359</a>         filterrad=filterrad,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3359'>3360</a>         resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3360'>3361</a>         url=url,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3361'>3362</a>         **({"data": data} if data is not None else {}),
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3362'>3363</a>         **kwargs,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3363'>3364</a>     )
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3364'>3365</a>     sci(__ret)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/pyplot.py?line=3365'>3366</a>     return __ret
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1461'>1462</a> @functools.wraps(func)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1462'>1463</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1463'>1464</a>     if data is None:
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1464'>1465</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1466'>1467</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1467'>1468</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/__init__.py?line=1468'>1469</a>                   or bound.kwargs.get(label_namer))
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5737, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5531'>5532</a> @_preprocess_data()
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5532'>5533</a> @_docstring.interpd
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5533'>5534</a> def imshow(self, X, cmap=None, norm=None, *, aspect=None,
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5536'>5537</a>            interpolation_stage=None, filternorm=True, filterrad=4.0,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5537'>5538</a>            resample=None, url=None, **kwargs):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5538'>5539</a>     """
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5539'>5540</a>     Display data as an image, i.e., on a 2D regular raster.
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5540'>5541</a>
#    (...)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5734'>5735</a>     (unassociated) alpha representation.
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5735'>5736</a>     """
# -> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5736'>5737</a>     im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5737'>5738</a>                           interpolation=interpolation, origin=origin,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5738'>5739</a>                           extent=extent, filternorm=filternorm,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5739'>5740</a>                           filterrad=filterrad, resample=resample,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5740'>5741</a>                           interpolation_stage=interpolation_stage,
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5741'>5742</a>                           **kwargs)
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5743'>5744</a>     if aspect is None and not (
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5744'>5745</a>             im.is_transform_set()
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5745'>5746</a>             and not im.get_transform().contains_branch(self.transData)):
#    <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=5746'>5747</a>         aspect = mpl.rcParams['image.aspect']
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py:912, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=895'>896</a> def __init__(self, ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=896'>897</a>              *,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=897'>898</a>              cmap=None,
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=906'>907</a>              **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=907'>908</a>              ):
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=909'>910</a>     self._extent = extent
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=911'>912</a>     super().__init__(
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=912'>913</a>         ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=913'>914</a>         cmap=cmap,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=914'>915</a>         norm=norm,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=915'>916</a>         interpolation=interpolation,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=916'>917</a>         origin=origin,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=917'>918</a>         filternorm=filternorm,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=918'>919</a>         filterrad=filterrad,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=919'>920</a>         resample=resample,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=920'>921</a>         interpolation_stage=interpolation_stage,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=921'>922</a>         **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=922'>923</a>     )
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py:261, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=247'>248</a> def __init__(self, ax,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=248'>249</a>              cmap=None,
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=249'>250</a>              norm=None,
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=257'>258</a>              **kwargs
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=258'>259</a>              ):
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=259'>260</a>     martist.Artist.__init__(self)
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=260'>261</a>     cm.ScalarMappable.__init__(self, norm, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=261'>262</a>     if origin is None:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/image.py?line=262'>263</a>         origin = mpl.rcParams['image.origin']
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:411, in ScalarMappable.__init__(self, norm, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=408'>409</a> self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=409'>410</a> self.cmap = None  # So that the setter knows we're initializing.
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=410'>411</a> self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=411'>412</a> #: The last colorbar associated with this ScalarMappable. May be None.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=412'>413</a> self.colorbar = None
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:600, in ScalarMappable.set_cmap(self, cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=590'>591</a> """
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=591'>592</a> Set the colormap for luminance data.
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=592'>593</a>
#    (...)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=595'>596</a> cmap : `.Colormap` or str or None
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=596'>597</a> """
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=597'>598</a> in_init = self.cmap is None
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=599'>600</a> self.cmap = _ensure_cmap(cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=600'>601</a> if not in_init:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=601'>602</a>     self.changed()
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py:739, in _ensure_cmap(cmap)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=735'>736</a> # use check_in_list to ensure type stability of the exception raised by
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=736'>737</a> # the internal usage of this (ValueError vs KeyError)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=737'>738</a> if cmap_name not in _colormaps:
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=738'>739</a>     _api.check_in_list(sorted(_colormaps), cmap=cmap_name)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/cm.py?line=739'>740</a> return mpl.colormaps[cmap_name]
#
# File ~/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py:129, in check_in_list(values, _print_supported_values, **kwargs)
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=126'>127</a> if _print_supported_values:
#     <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=127'>128</a>     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> <a href='file:///home/luke/.mambaforge/lib/python3.10/site-packages/matplotlib/_api/__init__.py?line=128'>129</a> raise ValueError(msg)
#
# ValueError: 'Magma' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
plt.imshow(np.log10(-inv_corr),cmap='BuGn')
plt.imshow(np.log10(-inv_corr))
# Out:
# <ipython-input-46-4a97e2d06f2f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-46-4a97e2d06f2f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-46-4a97e2d06f2f>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr))
# <ipython-input-46-4a97e2d06f2f>:2: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr))

# %%
plt.imshow(np.log10(-inv_corr),cmap='BuGn')
plt.imshow(np.log10(inv_corr))
# Out:
# <ipython-input-47-60b1827023a5>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-47-60b1827023a5>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-47-60b1827023a5>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(inv_corr))
# <ipython-input-47-60b1827023a5>:2: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(inv_corr))

# %%
plt.imshow(np.log10(-inv_corr),cmap='BuGn')
plt.imshow(np.log10(inv_corr),cmap='GnBu')
# Out:
# <ipython-input-48-45f49eb4471f>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-48-45f49eb4471f>:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(-inv_corr),cmap='BuGn')
# <ipython-input-48-45f49eb4471f>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(inv_corr),cmap='GnBu')
# <ipython-input-48-45f49eb4471f>:2: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(inv_corr),cmap='GnBu')

# %%
plt.imshow(np.log10(-inv_corr),cmap='BuGn')
plt.imshow(np.log10(inv_corr),cmap='GnBu')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb Cell 49 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#X66sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.imshow(np.log10(-inv_corr),cmap='BuGn')
#       <a href='vscode-notebook-cell://ssh-remote%2B10.81.205.13/home/luke/lukeflamingradis/EmFit_private/Inv_corr.ipynb#X66sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.imshow(np.log10(inv_corr),cmap='GnBu')
#
# NameError: name 'plt' is not defined
