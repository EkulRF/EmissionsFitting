# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle as pkl
import scipy
from radis import calc_spectrum
from radis import load_spec
from radis.test.utils import getTestFile
from radis import Spectrum

from inversion_tools_remastered import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Regularised inversion code
#
# Functions are defined in `inversion_tools`. We first define a few parameters, such as the species of interest, and the spectral ranges. We then load up the data, and subset things spectrally.

# %%
# Species and spectral bounds (in cm^{-1}) as a dictionary.
bounds = {
    "CO2": (6250, 6600),
    "CH4": [9100, 9700],
    "H2O": [5500, 5900],
    "CO": [2500, 4000],
}
selected_spectra = list(bounds.keys())

(spectra_obs, absorption_spectra, species_names, wv_obs) = read_data(
    selected_spectra,
    "spectra/test_series/", # Location of the series we want to invert.
    "spectra/templates/" # Location of the individual species "template" absorption
)
# Out:
# 100%|██████████| 567/567 [00:09<00:00, 61.50it/s]
# 100%|██████████| 4/4 [00:00<00:00, 43.71it/s]

# %%
import pickle
with open('compounds' + 'CH3OH' + '.pickle', 'rb') as handle:
    Compounds = pickle.load(handle)

# %%
from pathlib import Path
Freq_obs = np.array(wv_obs)
folder = Path("Calibration/")
files = {f.name:f for f in sorted(folder.rglob("**/*_1ppm_*"))
        if int(f.name.split("_")[3].split(" ")[-1]) > 800}

def getReferenceMatrix(Compounds, T, P, W_obs):
    
    output = []
    
    for c in Compounds:
        
        bank = Compounds[c]['Source']
        
        tmp = np.zeros_like(W_obs)
        
        for i in range(len(Compounds[c]['bounds'])):
            bound = Compounds[c]['bounds'][i]
            try:
                print(c, bound, bank)
                s = calc_spectrum(bound[0], bound[1],         # cm-1
                          molecule=c,
                          isotope='1',
                          pressure=P,   # bar
                          Tgas=T,           # K
                          mole_fraction=10**(-4),
                          path_length=500,      # cm
                          databank=bank,  # or 'hitemp', 'geisa', 'exomol'
                          )
            except:
                print("BAD", c)
                continue
            s.apply_slit(0.241, 'cm-1', shape="gaussian")       # simulate an experimental slit
            w, A = s.get('absorbance', wunit='cm-1')
           
            iloc, jloc = np.argmin(np.abs(w.min() - W_obs)), np.argmin(np.abs(w.max() - W_obs))
            s.resample(W_obs[iloc:jloc], energy_threshold=2)
            
            w, A = s.get('absorbance', wunit='cm-1')

            tmp[iloc:jloc] = A
            
        output.append(tmp)
    
    ref_mat = np.array(output)
    
    return ref_mat

T, P = 300, 1.01

storage_mtx = getReferenceMatrix(Compounds, T, P, wv_obs)
# Out:
# C2H2 [625, 830] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             C2H2
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          830.0000 cm-1
#    wavenum_min          625.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\C2H2.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.17s - Spectrum calculated
# C2H2 [1225, 1450] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             C2H2
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1450.0000 cm-1
#    wavenum_min          1225.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\C2H2.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.12s - Spectrum calculated
# H2CO [1630, 1850] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2CO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1850.0000 cm-1
#    wavenum_min          1630.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2CO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.13s - Spectrum calculated
# H2CO [2600, 3100] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2CO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3100.0000 cm-1
#    wavenum_min          2600.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2CO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.19s - Spectrum calculated
# NO2 [1525, 1675] hitemp
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             NO2
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1675.0000 cm-1
#    wavenum_min          1525.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitemp-radisdb
#    dbpath               C:\Users\luker\.radisdb\hitemp\NO2-10_HITEMP2019.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.23s - Spectrum calculated
# SiH [3600, 4000] exomol
# Using ExoMol database SiGHTLY for 28Si-1H (recommended by the ExoMol team). All available databases are ['xsec-SiGHTLY', 'Kurucz', 'SiGHTLY']. Select one of them with `radis.fetch_exomol(DATABASE_NAME)`, `SpectrumFactory.fetch_databank('exomol', exomol_database=DATABASE_NAME')`, or `calc_spectrum(..., databank=('exomol', DATABASE_NAME))`
#
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__H2.broad and saving as C:\Users\luker\.radisdb\exomol\SiH\28Si-1H\SiGHTLY\28Si-1H__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__H2.broad and save.
# Downloading http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__He.broad and saving as C:\Users\luker\.radisdb\exomol\SiH\28Si-1H\SiGHTLY\28Si-1H__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__He.broad and save.
# Downloading http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__air.broad and saving as C:\Users\luker\.radisdb\exomol\SiH\28Si-1H\SiGHTLY\28Si-1H__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH/28Si-1H/28Si-1H__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\SiH\28Si-1H\SiGHTLY\28Si-1H__SiGHTLY.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             SiH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          4000.0000 cm-1
#    wavenum_min          3600.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\SiH\28Si-1H\SiGHTLY
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.07s - Spectrum calculated
# CaF [2175, 2320] exomol
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# Using ExoMol database MoLLIST for 40Ca-19F
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__H2.broad and saving as C:\Users\luker\.radisdb\exomol\CaF\40Ca-19F\MoLLIST\40Ca-19F__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__H2.broad and save.
# Downloading http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__He.broad and saving as C:\Users\luker\.radisdb\exomol\CaF\40Ca-19F\MoLLIST\40Ca-19F__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__He.broad and save.
# Downloading http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__air.broad and saving as C:\Users\luker\.radisdb\exomol\CaF\40Ca-19F\MoLLIST\40Ca-19F__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/CaF/40Ca-19F/40Ca-19F__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\CaF\40Ca-19F\MoLLIST\40Ca-19F__MoLLIST.trans.bz2
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\api\exomolapi.py:1189: Warning:
#                     No default broadening exponent in def file. Assigned n = 0.5
#
#   warnings.warn(
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\api\exomolapi.py:1199: Warning:
#                     No default broadening in def file. Assigned alpha_ref = 0.07
#
#   warnings.warn(
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: LinestrengthCutoffWarning: Estimated error after discarding lines is large: 0.26%. Consider reducing cutoff
#   warnings.warn(WarningType(message))
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CaF
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          2320.0000 cm-1
#    wavenum_min          2175.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\CaF\40Ca-19F\MoLLIST
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.05s - Spectrum calculated
# SiS [1400, 1525] exomol
# Using ExoMol database UCTY for 28Si-32S (recommended by the ExoMol team). All available databases are ['xsec-UCTY', 'UCTY']. Select one of them with `radis.fetch_exomol(DATABASE_NAME)`, `SpectrumFactory.fetch_databank('exomol', exomol_database=DATABASE_NAME')`, or `calc_spectrum(..., databank=('exomol', DATABASE_NAME))`
#
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__H2.broad and saving as C:\Users\luker\.radisdb\exomol\SiS\28Si-32S\UCTY\28Si-32S__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__H2.broad and save.
# Downloading http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__He.broad and saving as C:\Users\luker\.radisdb\exomol\SiS\28Si-32S\UCTY\28Si-32S__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__He.broad and save.
# Downloading http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__air.broad and saving as C:\Users\luker\.radisdb\exomol\SiS\28Si-32S\UCTY\28Si-32S__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiS/28Si-32S/28Si-32S__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\SiS\28Si-32S\UCTY\28Si-32S__UCTY.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             SiS
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1525.0000 cm-1
#    wavenum_min          1400.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\SiS\28Si-32S\UCTY
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.04s - Spectrum calculated
# CH3Br [825, 1100] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CH3Br
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1100.0000 cm-1
#    wavenum_min          825.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CH3Br.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# 0.14s - Spectrum calculated
# CH3Br [1200, 1600] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CH3Br
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1600.0000 cm-1
#    wavenum_min          1200.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CH3Br.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.17s - Spectrum calculated
# CO [2000, 2250] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          2250.0000 cm-1
#    wavenum_min          2000.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.11s - Spectrum calculated
# CO [4100, 4350] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          4350.0000 cm-1
#    wavenum_min          4100.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.12s - Spectrum calculated
# H2S [1000, 1600] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1600.0000 cm-1
#    wavenum_min          1000.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.26s - Spectrum calculated
# H2S [2100, 3000] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3000.0000 cm-1
#    wavenum_min          2100.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.36s - Spectrum calculated
# H2S [3500, 4150] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          4150.0000 cm-1
#    wavenum_min          3500.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.29s - Spectrum calculated
# H2S [4900, 5300] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          5300.0000 cm-1
#    wavenum_min          4900.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.19s - Spectrum calculated
# H2S [6000, 6500] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          6500.0000 cm-1
#    wavenum_min          6000.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.22s - Spectrum calculated
# H2S [7250, 7750] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             H2S
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          7750.0000 cm-1
#    wavenum_min          7250.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\H2S.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.24s - Spectrum calculated
# BeH [1700, 2250] exomol
# Using ExoMol database Darby-Lewis for 9Be-1H (recommended by the ExoMol team). All available databases are ['Yadin-BeH', 'xsec-Darby', 'Darby-Lewis']. Select one of them with `radis.fetch_exomol(DATABASE_NAME)`, `SpectrumFactory.fetch_databank('exomol', exomol_database=DATABASE_NAME')`, or `calc_spectrum(..., databank=('exomol', DATABASE_NAME))`
#
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__H2.broad and saving as C:\Users\luker\.radisdb\exomol\BeH\9Be-1H\Darby-Lewis\9Be-1H__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__H2.broad and save.
# Downloading http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__He.broad and saving as C:\Users\luker\.radisdb\exomol\BeH\9Be-1H\Darby-Lewis\9Be-1H__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__He.broad and save.
# Downloading http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__air.broad and saving as C:\Users\luker\.radisdb\exomol\BeH\9Be-1H\Darby-Lewis\9Be-1H__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/BeH/9Be-1H/9Be-1H__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\BeH\9Be-1H\Darby-Lewis\9Be-1H__Darby-Lewis.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             BeH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          2250.0000 cm-1
#    wavenum_min          1700.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\BeH\9Be-1H\Darby-Lewis
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.08s - Spectrum calculated
# HF [3400, 4400] hitran
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             HF
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          4400.0000 cm-1
#    wavenum_min          3400.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\HF.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: AccuracyWarning: Some lines are too narrow (FWHM ~ 0.022 cm⁻¹) for the current spectral grid (wstep=0.01). Please reduce wstep to below 0.0072 cm⁻¹. You can use wstep='auto' to get the optimal spectral grid value. You can also ignore by setting `warnings={'AccuracyWarning':'ignore'}` or change the 'GRIDPOINTS_PER_LINEWIDTH_WARN_THRESHOLD' key of radis.config / your ~/radis.json (if you know what you're doing!)
#   warnings.warn(WarningType(message))
# 0.33s - Spectrum calculated
# NO [1700, 2000] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             NO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          2000.0000 cm-1
#    wavenum_min          1700.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\NO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.15s - Spectrum calculated
# NO [3550, 3800] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             NO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3800.0000 cm-1
#    wavenum_min          3550.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\NO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.11s - Spectrum calculated
# HCl [2500, 3120] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             HCl
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3120.0000 cm-1
#    wavenum_min          2500.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\HCl.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: AccuracyWarning: Some lines are too narrow (FWHM ~ 0.02 cm⁻¹) for the current spectral grid (wstep=0.01). Please reduce wstep to below 0.0066 cm⁻¹. You can use wstep='auto' to get the optimal spectral grid value. You can also ignore by setting `warnings={'AccuracyWarning':'ignore'}` or change the 'GRIDPOINTS_PER_LINEWIDTH_WARN_THRESHOLD' key of radis.config / your ~/radis.json (if you know what you're doing!)
#   warnings.warn(WarningType(message))
# 0.29s - Spectrum calculated
# HCl [5200, 5900] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             HCl
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          5900.0000 cm-1
#    wavenum_min          5200.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\HCl.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: AccuracyWarning: Some lines are too narrow (FWHM ~ 0.025 cm⁻¹) for the current spectral grid (wstep=0.01). Please reduce wstep to below 0.0083 cm⁻¹. You can use wstep='auto' to get the optimal spectral grid value. You can also ignore by setting `warnings={'AccuracyWarning':'ignore'}` or change the 'GRIDPOINTS_PER_LINEWIDTH_WARN_THRESHOLD' key of radis.config / your ~/radis.json (if you know what you're doing!)
#   warnings.warn(WarningType(message))
# 0.26s - Spectrum calculated
# NH [2800, 3450] exomol
# Using ExoMol database MoLLIST for 14N-1H
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/NH/14N-1H/14N-1H__H2.broad and saving as C:\Users\luker\.radisdb\exomol\NH\14N-1H\MoLLIST\14N-1H__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/NH/14N-1H/14N-1H__H2.broad and save.
# Downloading http://www.exomol.com/db/NH/14N-1H/14N-1H__He.broad and saving as C:\Users\luker\.radisdb\exomol\NH\14N-1H\MoLLIST\14N-1H__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/NH/14N-1H/14N-1H__He.broad and save.
# Downloading http://www.exomol.com/db/NH/14N-1H/14N-1H__air.broad and saving as C:\Users\luker\.radisdb\exomol\NH\14N-1H\MoLLIST\14N-1H__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/NH/14N-1H/14N-1H__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\NH\14N-1H\MoLLIST\14N-1H__MoLLIST.trans.bz2
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\api\exomolapi.py:1189: Warning:
#                     No default broadening exponent in def file. Assigned n = 0.5
#
#   warnings.warn(
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\api\exomolapi.py:1199: Warning:
#                     No default broadening in def file. Assigned alpha_ref = 0.07
#
#   warnings.warn(
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             NH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3450.0000 cm-1
#    wavenum_min          2800.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\NH\14N-1H\MoLLIST
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.12s - Spectrum calculated
# SiH2 [800, 1300] exomol
# Using ExoMol database CATS for 28Si-1H2 (recommended by the ExoMol team). All available databases are ['xsec-CATS', 'CATS']. Select one of them with `radis.fetch_exomol(DATABASE_NAME)`, `SpectrumFactory.fetch_databank('exomol', exomol_database=DATABASE_NAME')`, or `calc_spectrum(..., databank=('exomol', DATABASE_NAME))`
#
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__H2.broad and saving as C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS\28Si-1H2__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__H2.broad and save.
# Downloading http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__He.broad and saving as C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS\28Si-1H2__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__He.broad and save.
# Downloading http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__air.broad and saving as C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS\28Si-1H2__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/SiH2/28Si-1H2/28Si-1H2__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS\28Si-1H2__CATS__00000-01000.trans.bz2
# Reading C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS\28Si-1H2__CATS__01000-02000.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             SiH2
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1300.0000 cm-1
#    wavenum_min          800.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\SiH2\28Si-1H2\CATS
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# 1.64s - Spectrum calculated
# SiH2 [1800, 2200] exomol
# ...
# Error: Couldn't download .broad file at http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB\24Mg-1H__XAB.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             MgH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1600.0000 cm-1
#    wavenum_min          1180.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.07s - Spectrum calculated
# MgH [2600, 2900] exomol
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# Using ExoMol database XAB for 24Mg-1H (recommended by the ExoMol team). All available databases are ['Yadin', 'UGAMOP', 'xsec-XAB', 'MoLLIST-MgH', 'XAB']. Select one of them with `radis.fetch_exomol(DATABASE_NAME)`, `SpectrumFactory.fetch_databank('exomol', exomol_database=DATABASE_NAME')`, or `calc_spectrum(..., databank=('exomol', DATABASE_NAME))`
#
# Background atmosphere:  Air
# Downloading http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__H2.broad and saving as C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB\24Mg-1H__H2.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__H2.broad and save.
# Downloading http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__He.broad and saving as C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB\24Mg-1H__He.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__He.broad and save.
# Downloading http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__air.broad and saving as C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB\24Mg-1H__air.broad
# Error: Couldn't download .broad file at http://www.exomol.com/db/MgH/24Mg-1H/24Mg-1H__air.broad and save.
# Reading C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB\24Mg-1H__XAB.trans.bz2
# .broad is used.
# Warning: Cannot load .broad. The default broadening parameters are used.
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             MgH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          2900.0000 cm-1
#    wavenum_min          2600.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             exomol-radisdb
#    dbpath               C:\Users\luker\.radisdb\exomol\MgH\24Mg-1H\XAB
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           exomol
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.05s - Spectrum calculated
# ClO [800, 880] hitran
# C:\Users\luker\Anaconda3\envs\Flaming_Radis\lib\site-packages\radis\misc\warning.py:369: MissingPressureShiftWarning: Pressure-shift coefficient not given in database: assumed 0 pressure shift
#   warnings.warn(WarningType(message))
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             ClO
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          880.0000 cm-1
#    wavenum_min          800.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\ClO.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.08s - Spectrum calculated
# CH4 [1150, 1400] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CH4
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1400.0000 cm-1
#    wavenum_min          1150.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CH4.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.20s - Spectrum calculated
# CH4 [2850, 3200] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CH4
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3200.0000 cm-1
#    wavenum_min          2850.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\CH4.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.15s - Spectrum calculated
# C2H4 [800, 1100] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             C2H4
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1100.0000 cm-1
#    wavenum_min          800.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\C2H4.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.12s - Spectrum calculated
# C2H4 [1375, 1515] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             C2H4
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1515.0000 cm-1
#    wavenum_min          1375.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\C2H4.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.09s - Spectrum calculated
# C2H4 [2920, 3230] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             C2H4
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          3230.0000 cm-1
#    wavenum_min          2920.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\C2H4.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.09s - Spectrum calculated
# SO2 [1070, 1400] hitran
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             SO2
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1400.0000 cm-1
#    wavenum_min          1070.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             hitran
#    dbpath               C:\Users\luker\.radisdb\hitran\SO2.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.26s - Spectrum calculated
# CH3OH [970, 1080] geisa
# Calculating Equilibrium Spectrum
# Physical Conditions
# ----------------------------------------
#    Tgas                 300 K
#    Trot                 300 K
#    Tvib                 300 K
#    isotope              1
#    mole_fraction        0.0001
#    molecule             CH3OH
#    overpopulation       None
#    path_length          500 cm
#    pressure_mbar        1010.0 mbar
#    rot_distribution     boltzmann
#    self_absorption      True
#    state                X
#    vib_distribution     boltzmann
#    wavenum_max          1080.0000 cm-1
#    wavenum_min          970.0000 cm-1
# Computation Parameters
# ----------------------------------------
#    Tref                 296 K
#    add_at_used
#    broadening_method    voigt
#    cutoff               1e-27 cm-1/(#.cm-2)
#    dbformat             geisa
#    dbpath               C:\Users\luker\.radisdb\geisa\CH3OH-line_GEISA2020_asc_gs08_v1.hdf5
#    diluent              air
#    folding_thresh       1e-06
#    include_neighbouring_lines  True
#    memory_mapping_engine  auto
#    neighbour_lines      0 cm-1
#    optimization         simple
#    parfuncfmt           hapi
#    parsum_mode          full summation
#    pseudo_continuum_threshold  0
#    sparse_ldm           auto
#    truncation           50 cm-1
#    waveunit             cm-1
#    wstep                0.01 cm-1
#    zero_padding         -1
# ----------------------------------------
# 0.09s - Spectrum calculated

# %%
plt.scatter(wv_obs[np.all(storage_mtx == 0, axis=0)], spectra_obs[0][np.all(storage_mtx == 0, axis=0)],s=1)

# %%
S = np.array([s[~np.all(storage_mtx == 0, axis=0)] for s in spectra_obs])
S_l = np.array([np.log(x) for x in S])
W = wv_obs[~np.all(storage_mtx == 0, axis=0)]
# Out:
# C:\Users\luker\AppData\Local\Temp\ipykernel_28476\4110678604.py:2: RuntimeWarning: invalid value encountered in log
#   S_l = np.array([np.log(x) for x in S])

# %%
W
# Out:
# array([ 800.145,  800.386,  800.627, ..., 7799.184, 7799.425, 7799.666])

# %%
labels_new = [''.join(x.split(' ')[0:-2]) for x in labels]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 labels_new = [''.join(x.split(' ')[0:-2]) for x in labels]
#
# NameError: name 'labels' is not defined

# %%
storage_mtx = storage_mtx[:,~np.all(storage_mtx == 0, axis=0)]

fig, ax = plt.subplots(figsize=(10,10))

fig.canvas.draw()

ax.spy(storage_mtx, aspect = 1/0.002)

ax.set_yticks(np.arange(0,17,1))
#ax.set_yticklabels(labels_new, fontsize=14)
#ax.set_xticklabels([int(W[x]) for x in [-500, 0,500,1000,1500,2000,2500,3000,3500, len(W)-1]], fontsize=14)

ax.set_xlabel('Wavenumber / cm$^{-1}$', fontsize=14)
ax.xaxis.set_label_position('top') 

plt.show()
import scipy.sparse as sprs
fig, ax = plt.subplots(figsize=(10,10))

storage_mtx_SM = sprs.csr_matrix(storage_mtx)

cmap = matplotlib.cm.viridis  # Can be any colormap that you want after the cm

d= storage_mtx_SM.todense()
ax.imshow(d,interpolation='none',cmap=cmap, aspect = 1/0.0025)

ax.set_yticks(np.arange(0,17,1))
#ax.set_yticklabels(labels_new, fontsize=14)
#ax.set_xticklabels([int(W[x]) for x in [-500, 0,500,1000,1500,2000,2500,3000,3500, len(W)-1]], fontsize=14)

ax.set_xlabel('Wavenumber / cm$^{-1}$', fontsize=14)
# Out:
# Text(0.5, 0, 'Wavenumber / cm$^{-1}$')

# %%
# Note that the remove_background still take bounds_clip as input. This doesn't do anything, I will get round to removing soon.

# Simple background removal and subsetting.
residual_spectra = remove_background(S_l, {}, W)
# Subsetting of the absorption spectra.

reference_spectra = storage_mtx[:, ~np.all(storage_mtx == 0, axis=0)]

# %% [markdown]
# # One by one inversion
#
# This is how you invert individual timesteps (or individual spectra for that matter).
#
# Shown for the two first time steps and timesteps 300 and 350

# %%
for tstep in [0, 1, 300, 350]:
    x_sol = np.linalg.lstsq(reference_spectra.T, residual_spectra[tstep, :], rcond=None)
    print(tstep, "=>", x_sol[0])
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[37], line 2
#       1 for tstep in [0, 1, 300, 350]:
# ----> 2     x_sol = np.linalg.lstsq(reference_spectra.T, residual_spectra[tstep, :], rcond=None)
#       3     print(tstep, "=>", x_sol[0])
#
# File <__array_function__ internals>:200, in lstsq(*args, **kwargs)
#
# File ~\Anaconda3\envs\Flaming_Radis\lib\site-packages\numpy\linalg\linalg.py:2285, in lstsq(a, b, rcond)
#    2282 if n_rhs == 0:
#    2283     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2284     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2285 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2286 if m == 0:
#    2287     x[...] = 0
#
# File ~\Anaconda3\envs\Flaming_Radis\lib\site-packages\numpy\linalg\linalg.py:101, in _raise_linalgerror_lstsq(err, flag)
#     100 def _raise_linalgerror_lstsq(err, flag):
# --> 101     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %% [markdown]
# # Regularised inversion
#
# Now for the regularised inversion. This also returns uncertainty (not complete, as I don't really know what the observational error in the data is). Note that the function returns the variance of the posterior distribution, so we need to take the square root. Here I plot the maximum a posteriori and $\pm \sigma/2$, for good measure.

# %%
gamma_selection = np.loadtxt("gamma_selection.csv")[:-1]
gamma_selection = np.array([0.001, 0.001, 0.001, 0.001,
       0.001, 0.001, 0.001, 0.001,
       0.0001, 0.000001, 0.001, 0.001,
       0.001, 0.001, 0.001, 0.001])

# %%
x_sol,sigma, C = temporally_regularised_inversion(reference_spectra, residual_spectra,
                                                  0.001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 x_sol,sigma, C = temporally_regularised_inversion(reference_spectra, residual_spectra,
#       2                                                   0.001)
#
# NameError: name 'reference_spectra' is not defined

# %%
# Calibration now. Will this affect sigma or C??

with open('CalibrationData.pkl', 'rb') as f:
    cal_temp = pkl.load(f)

prev = ''
cal = {}
for x in cal_temp.keys():
    a = x.split(' ')[0]
    if a != prev:
        cal[x] = cal_temp[x]
    prev = a
    
cal.pop('C2H2')
cal.pop('Toluene ')

nt = residual_spectra.shape[0]

# %%
def ConvertToConc(x_sol, cal, nt):
    
    new_sol = []
    
    for i, x in enumerate(cal.keys()):
        spec_sol = x_sol[i*nt:(i+1)*nt]

        f = scipy.interpolate.interp1d(cal[x]['NormalisationInfo'][0],cal[x]['NormalisationInfo'][1])
        
        for j in range(len(spec_sol)):
            try:
                new_sol.append(f(spec_sol[j]))
            except:
                #print("unphysical")
                new_sol.append(spec_sol[j])
            
    return new_sol

# %%
new_sol = ConvertToConc(x_sol, cal, nt)

# %%
import colorsys

def HSVToRGB(h, s, v): 
    (r, g, b) = colorsys.hsv_to_rgb(h, s, v) 
    return (int(255*r), int(255*g), int(255*b)) 

def getDistinctColors(n): 
    huePartition = 1.0 / (n + 1) 
    return (HSVToRGB(huePartition * value, 1.0, 1.0) for value in range(0, n))

def rgb2hex(rgb):
    return "#{:02x}{:02x}{:02x}".format(rgb[0],rgb[1],rgb[2])

def hilo(a, b, c):
    if c < b: b, c = c, b
    if b < a: a, b = b, a
    if c < b: b, c = c, b
    return a + c

def complement(col):
    r, g, b = col[0], col[1], col[2]
    k = hilo(r, g, b)
    return tuple(k - u for u in (r, g, b))

# %%
fig, axs = plt.subplots(nrows=8, ncols=2, figsize= (20,15),sharex=True)
axs = axs.flatten()
nt = residual_spectra.shape[0]
colours = getDistinctColors(len(labels_new))

for i, spc in enumerate(labels_new):
    try:
        col = next(colours)
        c = rgb2hex(col)
        c_comp = rgb2hex(complement(col))
        axs[i].plot(np.arange(nt), new_sol[i*nt:(i+1)*nt], color = 'red')
        axs[i].fill_between(np.arange(nt), new_sol[i*nt:(i+1)*nt] - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            color= "0.8")
        axs[i].set_title(spc, fontsize=20)
        axs[i].tick_params(labelsize=20)
    except:
        continue

fig.text(0.5, -0.001, 'Time Step', ha='center', fontsize=20)
fig.text(-0.003, 0.5, '$\sim$ Concentration (ish)', va='center', rotation='vertical', fontsize=20)

fig.tight_layout()

# %%
x_sol,sigma, C = temporally_regularised_inversion2(reference_spectra, residual_spectra,
                                                  gamma_selection)

# %%
new_sol = ConvertToConc(x_sol, cal, nt)

# %%
fig, axs = plt.subplots(nrows=8, ncols=2, figsize= (20,15),sharex=True)
axs = axs.flatten()
nt = residual_spectra.shape[0]
colours = getDistinctColors(len(labels_new))

for i, spc in enumerate(labels_new):
    try:
        col = next(colours)
        c = rgb2hex(col)
        c_comp = rgb2hex(complement(col))
        axs[i].plot(np.arange(nt), new_sol[i*nt:(i+1)*nt], color = 'red')
        axs[i].fill_between(np.arange(nt), new_sol[i*nt:(i+1)*nt] - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            color= "0.8")
        axs[i].set_title(spc, fontsize=20)
        axs[i].tick_params(labelsize=20)
    except:
        continue

fig.text(0.5, -0.001, 'Time Step', ha='center', fontsize=20)
fig.text(-0.003, 0.5, '$\sim$ Concentration (ish)', va='center', rotation='vertical', fontsize=20)

fig.tight_layout()

# %%
fig, axs = plt.subplots(nrows=8, ncols=2, figsize= (20,15),sharex=True)
axs = axs.flatten()
nt = residual_spectra.shape[0]
colours = getDistinctColors(len(labels_new))

for i, spc in enumerate(labels_new):
    try:
        col = next(colours)
        c = rgb2hex(col)
        c_comp = rgb2hex(complement(col))
        arr = [x-new_sol[i*nt:(i+1)*nt][0] for x in new_sol[i*nt:(i+1)*nt]]
        axs[i].plot(np.arange(nt), arr, color = 'red')
        axs[i].fill_between(np.arange(nt), arr - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            arr + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]),
                            color= "0.8")
        axs[i].set_title(spc, fontsize=20)
        axs[i].tick_params(labelsize=20)
    except:
        continue

fig.text(0.5, -0.001, 'Time Step', ha='center', fontsize=20)
fig.text(-0.003, 0.5, '$\sim$ Concentration (ish)', va='center', rotation='vertical', fontsize=20)

fig.tight_layout()

# %% [markdown]
# Code below trials the model over N $\gamma$ values and optimises values. These values are loaded earlier for actual use

# %%
def Euclidean_Norm(arr):
    t = 0
    for x in arr:
        t += x**2
    return np.sqrt(t)

Gam_Range = np.logspace(-8, 2.5, num=200)

# %%
# Resid_norm = []
# Soln_norm = []

# for gamma in Gam_Range:
#     x_sol,sigma, C = temporally_regularised_inversion(reference_spectra, residual_spectra, gamma)
    
#     for i in range(len(labels_new)):
#         sol = x_sol[i*nt:(i+1)*nt]
#         resid = np.sqrt(sigma[i*nt:(i+1)*nt])
        
#         if len(Resid_norm) < len(labels_new):
#             Resid_norm.append([])
#             Soln_norm.append([])
        
#         Resid_norm[i].append(Euclidean_Norm(resid))
#         Soln_norm[i].append(Euclidean_Norm(sol))

# np.savetxt("Resid_Norms3.csv", Resid_norm, delimiter=",")
# np.savetxt("Soln_Norms3.csv", Soln_norm, delimiter=",")

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
viridis = cm.get_cmap('viridis', 12)
norm = mpl.colors.Normalize(vmin=np.log10(Gam_Range).min(), vmax=np.log10(Gam_Range).max())

for i in range(len(Resid_norm)):
    
    fig, ax = plt.subplots()
    
    for x in range(len(Resid_norm[i])):
        ax.scatter(Resid_norm[i][x], Soln_norm[i][x], color = viridis(norm(np.log10(Gam_Range[x]))))
    #plt.xscale('log')
    ax.set_title(labels_new[i], fontsize=15)
    ax.set_xlabel('$\\vert$$\\vert$Residual$\\vert$$\\vert_2$', fontsize=15)
    ax.set_ylabel('$\\vert$$\\vert$Solution$\\vert$$\\vert_2$', fontsize=15)
    ax.tick_params(labelsize=15)
    cbar = fig.colorbar(cm.ScalarMappable(norm=norm, cmap=viridis), ax=ax)
    cbar.ax.set_yticklabels(['10$^{-8}$', '10$^{-6}$', '$10^{-4}$', '$10^{-2}$', '$1$', '$10^{2}$'], fontsize=15)
    cbar.ax.set_ylabel('$\gamma$', rotation=0, fontsize=15)
    plt.show()

# %%
for i in range(len(Resid_norm)):
    
    fig, ax = plt.subplots()
    
    for x in range(len(Resid_norm[i])):
        ax.scatter(Resid_norm[i][x], np.gradient(Soln_norm[i])[x], color = viridis(norm(np.log10(Gam_Range[x]))))
    #plt.xscale('log')
    ax.set_title(labels_new[i], fontsize=15)
    ax.set_xlabel('$\\vert$$\\vert$Residual$\\vert$$\\vert_2$', fontsize=15)
    ax.set_ylabel('Grad($\\vert$$\\vert$Solution$\\vert$$\\vert_2$)', fontsize=15)
    ax.tick_params(labelsize=15)
    cbar = fig.colorbar(cm.ScalarMappable(norm=norm, cmap=viridis), ax=ax)
    cbar.ax.set_yticklabels(['10$^{-8}$', '10$^{-6}$', '$10^{-4}$', '$10^{-2}$', '$1$', '$10^{2}$'], fontsize=15)
    cbar.ax.set_ylabel('$\gamma$', rotation = 0, fontsize=15)
    plt.show()

# %%
gamma_selection = []

for x in Soln_norm:
    index = np.where(abs(np.gradient(x)) == max(abs(np.gradient(x))))
    gamma_selection.append(Gam_Range[index][0])

# %% [markdown]
# Below will be loading up results from OPUS GA for comparison

# %%
import pandas as pd
df = pd.read_csv('spectra/OPUS_results.txt', sep='\t')

# %%
df.keys()
# Out:
# Index(['Date', 'Time', 'Acetic Acid', 'Acetone', 'Ammonia', 'C2H2', 'C2H4',
#        'C3H6', 'CH4', 'CO', 'CO2', 'Cyclopentene', 'Ethanol', 'Formaldehyde',
#        'Formic Acid', 'Furan', 'Glycolaldehyde', 'H2O', 'HCl', 'HCN',
#        'Isobutylene', 'Methanol', 'Methyl Formate', 'Methylpropionate', 'N2O',
#        'Nitrous Acid', 'NO', 'NO2', 'Ozone', 'SO2'],
#       dtype='object')

# %%
plt.plot(df['CO2'])
i = 9

array = new_sol[i*nt:(i+1)*nt]
ind = np.where(array==max(array))[0][0]
ind2 = np.where(df['CO2']==max(df['CO2']))[0][0]
diff = ind - ind2

plt.plot([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], array[diff:], color = 'red')
plt.fill_between([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], (array - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:],
                    (new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:], color= "0.8")

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Time Step')
ax1.set_ylabel('Weight from our model', color=color)
ax1.plot([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in array[diff:]], color = 'red')
ax1.fill_between([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in(array - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]],
                    [x - array[diff:][0] for x in (new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]], color= "0.8")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Concentration from OPUS GA (substracting minima)', color=color)  # we already handled the x-label with ax1
ax2.plot([x - df['CO2'][0] for x in df['CO2']], color = color)
ax2.tick_params(axis='y', labelcolor=color)

ax2.set_ylim(-100,1500)
ax1.set_ylim(-100,2000)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
fig, ax1 = plt.subplots()
i = 9
array = new_sol[i*nt:(i+1)*nt]
ind = np.where(array==max(array))[0][0]
ind2 = np.where(df['CO2']==max(df['CO2']))[0][0]
diff = ind - ind2


ax1.plot([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in array[diff:]], color = 'red')
ax1.fill_between([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in(array - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]],
                    [x - array[diff:][0] for x in (new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]], color= "0.8")
ax1.tick_params(axis='y')

ax1.set_ylabel('Concentration')  # we already handled the x-label with ax1
ax1.plot([x - df['CO2'][0] for x in df['CO2']], color = color)
ax1.set_title('CO2')
# Out:
# Text(0.5, 1.0, 'CO2')

# %%
i = 8

array = new_sol[i*nt:(i+1)*nt]
ind = np.where(array==max(array))[0][0]
ind2 = np.where(df['CO']==max(df['CO']))[0][0]
diff = ind - ind2


fig, ax1 = plt.subplots()


ax1.plot([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in array[diff:]], color = 'red')
ax1.fill_between([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in(array - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]],
                    [x - array[diff:][0] for x in (new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]], color= "0.8")
ax1.tick_params(axis='y')

ax1.set_ylabel('Concentration')  # we already handled the x-label with ax1
ax1.plot([x - df['CO'][0] for x in df['CO']], color = color)
ax1.set_title('CO')
# Out:
# Text(0.5, 1.0, 'CO')

# %%
i = 3

array = new_sol[i*nt:(i+1)*nt]
ind = np.where(array==max(array))[0][0]
ind2 = np.where(df['C2H4']==max(df['C2H4']))[0][0]
diff = ind - ind2


fig, ax1 = plt.subplots()


ax1.plot([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in array[diff:]], color = 'red', label='Model')
ax1.fill_between([x - np.arange(nt)[diff:][0] for x in np.arange(nt)[diff:]], [x - array[diff:][0] for x in(array - 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]],
                    [x - array[diff:][0] for x in (new_sol[i*nt:(i+1)*nt] + 0.5*np.sqrt(sigma[i*nt:(i+1)*nt]))[diff:]], color= "0.8")
ax1.tick_params(axis='y')

ax1.set_ylabel('Concentration')  # we already handled the x-label with ax1
ax1.set_title('C2H4')
ax1.plot([x - df['C2H4'][0] for x in df['C2H4']], color = color, label= 'OPUS')

plt.legend()
